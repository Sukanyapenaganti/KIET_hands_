# %%
num1 = 200
print(num1)
print(type(num1))
# Out:
# 200
# <class 'int'>

# %%
num2 = 20.45
print(num2)
print(type(num2))
# Out:
# 20.45
# <class 'float'>

# %%
#tuple
number_tuple = (10,20,30,40,50)
name_tuple = ("alice","bob","charcles")
print(number_tuple)
print(type(number_tuple))
# Out:
# (10, 20, 30, 40, 50)
# <class 'tuple'>

# %%
#set
number_set = {10,20,30,40}
print(number_set)
print(type(number_set))
print(len(number_set))
# Out:
# {40, 10, 20, 30}
# <class 'set'>
# 4

# %%
#map
car = {"brand" : "TATA" ,
       "model" : "nexon" ,
       "year" : 2023
       }
print(car)
print(car["brand"])
print(type(car))
# Out:
# {'brand': 'TATA', 'model': 'nexon', 'year': 2023}
# TATA
# <class 'dict'>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 name = "alice"
#       2 math_score = 85
# ----> 3 science_score
#
# NameError: name 'science_score' is not defined

# %%
value1 = True
value2 = False
print(value1)
print(type(value1))
# Out:
# True
# <class 'bool'>

# %%
name = "KIET group of institute"
print(name)
print(name[0])
print(len(name))
print(type(name))
# Out:
# KIET group of institute
# K
# 23
# <class 'str'>
