# %%
num1 = int(input("enter the first number"))
num2 = int(input("enter the second number"))
print(type(num1))
print(type(num2))

#type casting
num_int1 = int(num1)
num_int2 = int(num2)

print(type(num_int1))
print(type(num_int2))

sum = num1 + num2
sum_int = num_int1 + num_int2
print(sum)
print(sum_int)
11
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# 101
# 101
# 11

# %%
number1 = int(input("enter the first number"))
number2 = int(input("enter the second number"))
sum = number1 + number2
print("the sum is :", sum)
# Out:
# the sum is : 112

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
sum = num1 + num2
print("Addition is:", sum)
# Out:
# Addition is: 145.0

# %%
weight = float(input("enter your weight in kg :"))
height = float(input("enter your height in meters :"))
BMI = weight / (height ** 2)
print("your BMI is: ", BMI)
# Out:
# your BMI is:  31.25

# %%
name = "sukanya"
password = "hellofrnds@12"
#slice
print(name[0:6])

#lenth
print(len(name))
print(len(password))

#indexing
print(len(name))
print(len(password))
# Out:
# sukany
# 7
# 13
# 7
# 13

# %%
name = "sukanya"
password = "hellofrnds@12" 
print(len(name))
#trim
trim_name = name. strip()
print(len(trim_name))
#replace
replace_name = name.replace('i' , '@')
print(replace_name)
# Out:
# 7
# 7
# sukanya

# %%
name = "sukanya"
password = "sukanya@1234"

#slice
print(name[0:6])
print(name[0:3])
print(password[1:5])
print(password[1:8])

#lenth
print(len(name))
print(len(password))

#indexing 
print(name[0])
print(password[6])
# Out:
# sukany
# suk
# ukan
# ukanya@
# 7
# 12
# s
# a

# %%
from fileinput import filename


name = "sukanya"
password = "sukanay@123"

full_name = "penaganti sukanya"
full_name2 = "@ hello everyone "

#upper
upper_name = full_name.upper()
print(upper_name)



#split
split_name = full_name.split('@')
print(split_name)

split_name = full_name2.split('@')
print(split_name)

#trim
trim_name = name. strip()
print(len(trim_name))

#slice
print(name[0:6])
print(name[0:3])
print(password[1:5])
print(password[1:8])

#lenth
print(len(name))
print(len(password))

#indexing 
print(name[0])
print(password[6])


#replace
replace_name = name.replace('i' , '@')
print(replace_name)
# Out:
# PENAGANTI SUKANYA
# ['penaganti sukanya']
# ['', ' hello everyone ']
# 7
# sukany
# suk
# ukan
# ukanay@
# 7
# 11
# s
# y
# sukanya

# %%
name = "sukanya"
password = "sukanay@123"

full_name = "penaganti sukanya"
full_name2 = "@ hello everyone "

#ispiha
print(name.isalpha())   #alphabet
print(name.isnumeric())  #only number
print(name.isalnum())      #alhabet or number or combine

#upper
upper_name = full_name.upper()
print(upper_name)



#split
split_name = full_name.split('@')
print(split_name)

split_name = full_name2.split('@')
print(split_name)

#trim
trim_name = name. strip()
print(len(trim_name))

#slice
print(name[0:6])
print(name[0:3])
print(password[1:5])
print(password[1:8])  

#lenth
print(len(name))
print(len(password))

#indexing 
print(name[0])
print(password[6])


#replace
replace_name = name.replace('i' , '@')
print(replace_name)
# Out:
# True
# False
# True
# PENAGANTI SUKANYA
# ['penaganti sukanya']
# ['', ' hello everyone ']
# 7
# sukany
# suk
# ukan
# ukanay@
# 7
# 11
# s
# y
# sukanya

# %%
full_name = "edunet foundation"
first_name = full_name[0:6]
last_name = full_name[7:]
print(first_name)
print(last_name)
# Out:
# edunet
# foundation

# %%
phrase = "data science is amazing"
print(phrase.replace("awesome" , "awazing"))
# Out:
# data science is amazing

# %%
url = "http://www.edunet foundation"
print(url[8:])
# Out:
# ww.edunet foundation
